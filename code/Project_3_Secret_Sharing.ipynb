# %%
pip install phe
# Out:
# Requirement already satisfied: phe in /usr/local/lib/python3.10/dist-packages (1.5.0)

# %%
import time
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import plotly.express as px
from sympy import symbols, Poly, simplify
import random
from phe import paillier

# %%
random.seed(42)

def generate_random_values(num_parties, values_per_party, num_experiments):
    random_values = {}
    for experiment in range(num_experiments):
        experiment_data = {}
        for party in range(num_parties):
            values = [random.randint(1, 1000) for _ in range(values_per_party)]
            experiment_data[party] = values
        random_values[experiment] = experiment_data
    return random_values

# %%
def no_privacy_protection(num_parties, values_per_party, num_experiments, random_values):
    def generate_data(num_parties, values_per_party, random_values):
        data = {}
        for party in range(num_parties):
            data[party] = random_values[party]  # Use random values from the argument
        return data

    def compute_average(data, num_parties, values_per_party):
        total_sum = 0
        total_count = 0

        for party in range(num_parties):
            total_sum += sum(data[party])
            total_count += len(data[party])

        average = total_sum / total_count
        return average

    average_runtimes = []
    results = []

    for experiment in range(num_experiments):
        data = generate_data(num_parties, values_per_party, random_values[experiment])

        start_time = time.time()  # Record start time
        average = compute_average(data, num_parties, values_per_party)
        end_time = time.time()  # Record end time

        runtime = end_time - start_time
        average_runtimes.append(runtime)
        results.append((average, runtime))

    average_runtime = sum(average_runtimes) / num_experiments


    print(f"Results for n = {num_parties} (No Privacy Protection SMPC):")
    for i, (result, runtime) in enumerate(results):
        print(f"Experiment {i + 1} - Runtime: {runtime} seconds")
        print(f"Result: {result}")
    print(f"Average Runtime for n = {num_parties}: {average_runtime} seconds\n")
    print()

    return average_runtime

# %%
def shamir_secret_sharing(num_parties, values_per_party, num_experiments, secret, random_values):
    def share_secret(secret, num_parties, threshold):
        prime_num = 82171  # a large prime number
        coefficients = [secret] + [random.randint(1, prime_num - 1) for _ in range(threshold - 1)]
        x = symbols('x')
        polynomial = sum(coeff * x**i for i, coeff in enumerate(coefficients)) % prime_num
        points = [(i, polynomial.subs(x, i)) for i in range(1, num_parties + 1)]
        return points

    def interpolate(points, num_parties):
        x, y = symbols('x y')
        lagrange_basis = 0
        for xi, yi in points:
            basis = yi
            for xj, _ in points:
                if xj != xi:
                    basis *= (x - xj) / (xi - xj)
            lagrange_basis += basis


        # Create a SymPy expression from the computed Lagrange basis
        result = Poly(lagrange_basis, x).as_expr()

        return result

    total_runtime = 0
    results = []

    for _ in range(num_experiments):
        start_time = time.time()

        # Sharing the secret
        shares = share_secret(secret, num_parties, num_parties // 2)

        # Combining shares
        result = interpolate(shares[:num_parties // 2], num_parties)

        end_time = time.time()
        runtime = end_time - start_time
        total_runtime += runtime

        results.append((result, runtime))

    average_runtime = total_runtime / num_experiments

    print(f"Results for n = {num_parties} (Shamir's Secret Sharing SMPC):")
    for i, (result, runtime) in enumerate(results):
        print(f"Experiment {i + 1} - Runtime: {runtime} seconds")
        print(f"Result: {result}")
    print(f"Average Runtime for n = {num_parties}: {average_runtime} seconds\n")

    return average_runtime

# %%
def paillier_encryption(num_parties, values_per_experiment, num_experiments, random_values):
    def generate_paillier_keypair():
        public_key, private_key = paillier.generate_paillier_keypair()
        return public_key, private_key

    def paillier_encrypt(public_key, plaintext):
        encrypted_value = public_key.encrypt(plaintext)
        return encrypted_value

    def paillier_decrypt(private_key, ciphertext):
        decrypted_value = private_key.decrypt(ciphertext)
        return decrypted_value


    runtimes = []

    total_runtime = 0
    experiment_results = []

    for i in range(num_experiments):
        integer_values = random_values[i]

        start_time = time.time()

        public_key, private_key = generate_paillier_keypair()
        encrypted_values = [paillier_encrypt(public_key, val) for val in integer_values]
        sum_encrypted = sum(encrypted_values)
        average_encrypted = paillier_decrypt(private_key, sum_encrypted)

        end_time = time.time()
        runtime = end_time - start_time
        total_runtime += runtime

        experiment_results.append((average_encrypted, runtime))

    average_runtime = total_runtime / num_experiments
    runtimes.append(average_runtime)

    print(f"Results for n = {num_parties} (Paillier Encryption SMPC):")
    for i, (result, runtime) in enumerate(experiment_results):
          print(f"Experiment {i + 1} - Runtime: {runtime} seconds")
          print(f"Result: {result}")
    print(f"Average Runtime for n = {num_parties}: {average_runtime} seconds\n")
    return average_runtime

# %%
values_of_n = [10, 30, 50, 70, 100]

def main():
    num_experiments = 5
    values_per_party = 5

    no_privacy_runtimes = []
    shamir_runtimes = []
    paillier_runtimes = []

    for n in values_of_n:
        num_parties = n

        random_values = generate_random_values(num_parties, values_per_party, num_experiments)

        print(f"Running experiments for n = {num_parties} with No Privacy Protection SMPC:")
        runtime = no_privacy_protection(num_parties, values_per_party, num_experiments, random_values)
        no_privacy_runtimes.append(runtime)

        print(f"Running experiments for n = {num_parties} with Shamir's Secret Sharing SMPC:")
        secret = 55
        runtime = shamir_secret_sharing(num_parties, values_per_party, num_experiments, secret, random_values)
        shamir_runtimes.append(runtime)

        print(f"Running experiments for n = {num_parties} with Paillier Encryption SMPC:")
        runtime = paillier_encryption(num_parties, values_per_party, num_experiments,random_values)
        paillier_runtimes.append(runtime)

    return no_privacy_runtimes, shamir_runtimes, paillier_runtimes

if __name__ == "__main__":
    no_privacy_runtimes, shamir_runtimes, paillier_runtimes = main()

    fig_no_privacy = px.line(x=values_of_n, y=no_privacy_runtimes, labels={'x': 'n', 'y': 'Runtime (seconds)'},
                            title='No Privacy Protection SMPC')

    fig_shamir = px.line(x=values_of_n, y=shamir_runtimes, labels={'x': 'n', 'y': 'Runtime (seconds)'},
                         title="Shamir's Secret Sharing SMPC")

    fig_paillier = px.line(x=values_of_n, y=paillier_runtimes, labels={'x': 'n', 'y': 'Runtime (seconds)'},
                           title='Paillier Encryption SMPC')


    fig_combined = make_subplots(rows=1, cols=1)
    fig_combined.add_trace(go.Scatter(x=values_of_n, y=no_privacy_runtimes, mode='lines', name='No Privacy'))
    fig_combined.add_trace(go.Scatter(x=values_of_n, y=shamir_runtimes, mode='lines', name="Shamir's Secret Sharing"))
    fig_combined.add_trace(go.Scatter(x=values_of_n, y=paillier_runtimes, mode='lines', name='Paillier Encryption'))

    fig_combined.update_layout(
        title='Combined Runtimes for Different SMPC Approaches',
        xaxis_title='n',
        yaxis_title='Runtime (seconds)',)

    # Show the individual plots and the combined plot
    fig_no_privacy.show()
    fig_shamir.show()
    fig_paillier.show()
    fig_combined.show()
# Out:
# Running experiments for n = 10 with No Privacy Protection SMPC:
# Results for n = 10 (No Privacy Protection SMPC):
# Experiment 1 - Runtime: 5.0067901611328125e-06 seconds
# Result: 440.86
# Experiment 2 - Runtime: 2.384185791015625e-06 seconds
# Result: 464.74
# Experiment 3 - Runtime: 1.9073486328125e-06 seconds
# Result: 519.78
# Experiment 4 - Runtime: 2.1457672119140625e-06 seconds
# Result: 487.68
# Experiment 5 - Runtime: 1.9073486328125e-06 seconds
# Result: 538.58
# Average Runtime for n = 10: 2.6702880859375e-06 seconds
#
#
# Running experiments for n = 10 with Shamir's Secret Sharing SMPC:
# Results for n = 10 (Shamir's Secret Sharing SMPC):
# Experiment 1 - Runtime: 0.07258820533752441 seconds
# Result: 264403*x**4/24 - 1513301*x**3/12 + 11731769*x**2/24 - 8878741*x/12 + 410910
# Experiment 2 - Runtime: 0.06148219108581543 seconds
# Result: 11227*x**4 - 379886*x**3/3 + 485220*x**2 - 2206072*x/3 + 410910
# Experiment 3 - Runtime: 0.06114387512207031 seconds
# Result: 49701*x**4/8 - 1052057*x**3/12 + 3441587*x**2/8 - 10164343*x/12 + 575252
# Experiment 4 - Runtime: 0.0608820915222168 seconds
# Result: -17239*x**4/3 + 72064*x**3 - 963503*x**2/3 + 592026*x - 328629
# Experiment 5 - Runtime: 0.06365323066711426 seconds
# Result: -65819*x**4/24 + 378899*x**3/12 - 2859469*x**2/24 + 1978153*x/12 + 55
# Average Runtime for n = 10: 0.06394991874694825 seconds
#
# Running experiments for n = 10 with Paillier Encryption SMPC:
# Results for n = 10 (Paillier Encryption SMPC):
# Experiment 1 - Runtime: 7.371055603027344 seconds
# Result: 45
# Experiment 2 - Runtime: 8.019535541534424 seconds
# Result: 45
# Experiment 3 - Runtime: 4.225278377532959 seconds
# Result: 45
# Experiment 4 - Runtime: 9.946079969406128 seconds
# Result: 45
# Experiment 5 - Runtime: 4.43622088432312 seconds
# Result: 45
# Average Runtime for n = 10: 6.799634075164795 seconds
#
# Running experiments for n = 30 with No Privacy Protection SMPC:
# Results for n = 30 (No Privacy Protection SMPC):
# Experiment 1 - Runtime: 1.9073486328125e-05 seconds
# Result: 507.9
# Experiment 2 - Runtime: 9.059906005859375e-06 seconds
# Result: 498.9266666666667
# Experiment 3 - Runtime: 8.344650268554688e-06 seconds
# Result: 477.94666666666666
# Experiment 4 - Runtime: 8.58306884765625e-06 seconds
# Result: 538.7933333333333
# Experiment 5 - Runtime: 7.867813110351562e-06 seconds
# Result: 454.23333333333335
# Average Runtime for n = 30: 1.0585784912109375e-05 seconds
#
#
# Running experiments for n = 30 with Shamir's Secret Sharing SMPC:
# Results for n = 30 (Shamir's Secret Sharing SMPC):
# Experiment 1 - Runtime: 0.5868716239929199 seconds
# Result: 67074577*x**14/87178291200 - 156169867*x**13/1779148800 + 1449454561*x**12/319334400 - 134813692613*x**11/958003200 + 253943159047*x**10/87091200 - 15269991363*x**9/358400 + 275221645683493*x**8/609638400 - 305892235863589*x**7/87091200 + 3239425511779*x**6/161280 - 113822300795627*x**5/1360800 + 929356789725913*x**4/3742200 - 10106975534041571*x**3/19958400 + 25149314352205529*x**2/37837800 - 179036776719719*x/360360 + 156946665
# Experiment 2 - Runtime: 0.5677671432495117 seconds
# Result: -32793161*x**14/21794572800 + 1025760871*x**13/6227020800 - 781877897*x**12/95800320 + 115983834941*x**11/479001600 - 8354780591*x**10/1741824 + 972116224907*x**9/14515200 - 41340179386883*x**8/60963840 + 219672358998493*x**7/43545600 - 1202845119791299*x**6/43545600 + 2403264607166701*x**5/21772800 - 7554071508918031*x**4/23950080 + 12400301845830989*x**3/19958400 - 29940724687811477*x**2/37837800 + 207872837891843*x/360360 - 178639699
# Experiment 3 - Runtime: 0.5637950897216797 seconds
# Result: -2868457*x**14/4151347200 + 331237609*x**13/4151347200 - 266566843*x**12/63866880 + 542526049*x**11/4147200 - 79492073663*x**10/29030400 + 1172397046529*x**9/29030400 - 2505264392243*x**8/5806080 + 14021852248267*x**7/4147200 - 282264644466631*x**6/14515200 + 84306245835071*x**5/1036800 - 1931809984424933*x**4/7983360 + 4925469059131549*x**3/9979200 - 1165264203998117*x**2/1801800 + 7890372761549*x/16380 - 151358927
# Experiment 4 - Runtime: 0.77679443359375 seconds
# Result: 304706167*x**14/87178291200 - 4862541973*x**13/12454041600 + 18936932737*x**12/958003200 - 574899681149*x**11/958003200 + 1060776136109*x**10/87091200 - 1688015961697*x**9/9676800 + 1105368680481847*x**8/609638400 - 1206460471969357*x**7/87091200 + 424010085152491*x**6/5443200 - 3477760858889857*x**5/10886400 + 56022225198848327*x**4/59875200 - 37629091876296713*x**3/19958400 + 185385019606485509*x**2/75675600 - 654326784966263*x/360360 + 569527256
# Experiment 5 - Runtime: 0.5582413673400879 seconds
# Result: 1996835*x**14/1162377216 - 32167435*x**13/166053888 + 3163538317*x**12/319334400 - 97072819771*x**11/319334400 + 36228733301*x**10/5806080 - 4999965611*x**9/55296 + 193320040705787*x**8/203212800 - 213607252794283*x**7/29030400 + 3039725752339*x**6/72576 - 126141019065961*x**5/725760 + 5136633290798201*x**4/9979200 - 995755208865881*x**3/950400 + 13857337507794409*x**2/10090080 - 61584599099399*x/60060 + 323425111
# Average Runtime for n = 30: 0.6106939315795898 seconds
#
# Running experiments for n = 30 with Paillier Encryption SMPC:
# Results for n = 30 (Paillier Encryption SMPC):
# Experiment 1 - Runtime: 11.51948618888855 seconds
# Result: 435
# Experiment 2 - Runtime: 12.938396453857422 seconds
# Result: 435
# Experiment 3 - Runtime: 10.375190496444702 seconds
# Result: 435
# Experiment 4 - Runtime: 9.64643931388855 seconds
# Result: 435
# Experiment 5 - Runtime: 9.551579713821411 seconds
# Result: 435
# Average Runtime for n = 30: 10.806218433380128 seconds
#
# Running experiments for n = 50 with No Privacy Protection SMPC:
# Results for n = 50 (No Privacy Protection SMPC):
# Experiment 1 - Runtime: 4.267692565917969e-05 seconds
# Result: 482.608
# Experiment 2 - Runtime: 1.9311904907226562e-05 seconds
# Result: 473.272
# Experiment 3 - Runtime: 1.7404556274414062e-05 seconds
# Result: 463.2
# Experiment 4 - Runtime: 1.8596649169921875e-05 seconds
# Result: 474.1
# Experiment 5 - Runtime: 1.8358230590820312e-05 seconds
# Result: 488.52
# Average Runtime for n = 50: 2.32696533203125e-05 seconds
#
#
# Running experiments for n = 50 with Shamir's Secret Sharing SMPC:
# Results for n = 50 (Shamir's Secret Sharing SMPC):
# Experiment 1 - Runtime: 1.8863451480865479 seconds
# Result: 79805659309*x**24/310224200866619719680000 - 346146709151*x**23/4308669456480829440000 + 79948757018401*x**22/6744004366665646080000 - 216029760647*x**21/196503623737344000 + 12591963080474689*x**20/175168944588718080000 - 25725144444999893*x**19/7298706024529920000 + 135676168998761227*x**18/1008373858652160000 - 285436223128057*x**17/69645090816000 + 384500774034982723541*x**16/3796230997278720000 - 324870051270656608637*x**15/158176291553280000 + 102691523670319877252681*x**14/2982752926433280000 - 28631795361083316319*x**13/59750659584000 + 231680265254284981868789521*x**12/41758540970065920000 - 2816176494121054995855149*x**11/52725430517760000 + 404684684108287095098813081*x**10/949057749319680000 - 683476586249585181639457*x**9/243348140851200 + 1246722991887919762683183373*x**8/82316233359360000 - 36084782927315707273472443*x**7/545656849920000 + 490195097248316953499127098797*x**6/2128789257154560000 - 1708698713959173382828802843*x**5/2729216996352000 + 20981039995075791728840087603*x**4/16261584603264000 - 5228204168762202943753482349*x**3/2710264100544000 + 32195888273165930599098031*x**2/16491024950400 - 486032245494129372133*x/411863760 + 315792767062
# Experiment 2 - Runtime: 1.9138860702514648 seconds
# Result: -32100051953*x**24/68938711303693271040000 + 439685237743*x**23/3041413733986467840000 - 10593401896919*x**22/499555879012270080000 + 1707044448847*x**21/873349438832640000 - 449481710080199*x**20/3538766557347840000 + 180680776920563191*x**19/29194824098119680000 - 38257865930639227*x**18/162969512509440000 + 597043508514547729*x**17/84031154887680000 - 49058156302030246627*x**16/281202296094720000 + 741299076453680047973*x**15/210901722071040000 - 38803642271242743826037*x**14/662833983651840000 + 402483592186156522081289*x**13/497125487738880000 - 86439526514531632442632141*x**12/9279675771125760000 + 56387670606418676941043389*x**11/632705166213120000 - 4519626935273669273310359*x**10/6390961274880000 + 18781521829177617086837011*x**9/4055802347520000 - 289040881766988222376678661*x**8/11640679464960000 + 609157445796986112594179237*x**7/5649153269760000 - 1590407388865916385113093718431*x**6/4257578514309120000 + 358611204795129802875454310053*x**5/354798209525760000 - 674421212008457809140594340177*x**4/325231692065280000 + 16737328980622151731828398817*x**3/5420528201088000 - 462130391156858520476371759*x**2/148419224553600 + 89689312362047885116*x/47805615 - 500750566971
# Experiment 3 - Runtime: 2.1579177379608154 seconds
# Result: 261432997129*x**24/620448401733239439360000 - 6799111254007*x**23/51704033477769953280000 + 261581260439281*x**22/13488008733331292160000 - 2186768771249*x**21/1216451004088320000 + 41166227254851469*x**20/350337889177436160000 - 168169045569372857*x**19/29194824098119680000 + 3547534963949896781*x**18/16133981738434560000 - 18011796380705562847*x**17/2688996956405760000 + 1257175670270355336401*x**16/7592461994557440000 - 4819488119798201923*x**15/1434705592320000 + 336139840278668735544881*x**14/5965505852866560000 - 97552909011687138166099*x**13/124281371934720000 + 759817055727522515950630621*x**12/83517081940131840000 - 55485723289260223330064063*x**11/632705166213120000 + 1330831425154507369334830691*x**10/1898115498639360000 - 34842659315077992900945121*x**9/7532204359680000 + 28799337039222923874938401951*x**8/1152427267031040000 - 10499658444392388475197671723*x**7/96035605585920000 + 541401291078979113676121929529*x**6/1419192838103040000 - 368795584906248724173459873257*x**5/354798209525760000 + 15515583280793486470259625109*x**4/7227370934784000 - 498163628960216525661554599*x**3/154872234316800 + 96832983858997155236102549*x**2/29683844910720 - 661085804803106221997*x/334639305 + 529513621750
# Experiment 4 - Runtime: 1.9823486804962158 seconds
# Result: 16473749221*x**24/68938711303693271040000 - 33682057433*x**23/449600291111043072000 + 326174638667*x**22/29385639941898240000 - 105629834406049*x**21/102181884343418880000 + 2642899080375569*x**20/38926432130826240000 - 229740855715303*x**19/68693703760281600 + 229973105845793347*x**18/1792664637603840000 - 1320002100041978611*x**17/336124619550720000 + 27431326355702002367*x**16/281202296094720000 - 19356584008506553859*x**15/9733925634048000 + 22214522005228348916977*x**14/662833983651840000 - 233170274506287805814899*x**13/497125487738880000 + 50675371561211005579569041*x**12/9279675771125760000 - 6690069047419953024425369*x**11/126541033242624000 + 29839189612089130567894109*x**10/70300574023680000 - 444707950749054631493850019*x**9/158176291553280000 + 1952085641124468484364516771*x**8/128047474114560000 - 1285487653498264602919472341*x**7/19207121117184000 + 58673282416557968226199592423*x**6/250445794959360000 - 227141900650899578648209165343*x**5/354798209525760000 + 431149453847550589897978327631*x**4/325231692065280000 - 48831588536942919142803979*x**3/24527276928000 + 428965093032954513261665*x**2/212027463648 - 19046858348844331921*x/15519504 + 329410391695
# Experiment 5 - Runtime: 2.7136988639831543 seconds
# Result: -194437471*x**24/36496964807837614080000 + 6824720783*x**23/3446935565184663552000 - 4570672090967*x**22/13488008733331292160000 + 228338315111*x**21/6386367771463680000 - 917996373189323*x**20/350337889177436160000 + 6246415502143*x**19/43901991124992000 - 96093103501144747*x**18/16133981738434560000 + 176851360153995239*x**17/896332318801920000 - 39981432774584856967*x**16/7592461994557440000 + 1318655847474057707*x**15/11503730294784000 - 12240648613982990707927*x**14/5965505852866560000 + 33685579187187565747*x**13/1109655106560000 - 31073790211169785346719547*x**12/83517081940131840000 + 53115222138467122272757*x**11/14060114804736000 - 60169868027766118938578677*x**10/1898115498639360000 + 34605038917769611903204451*x**9/158176291553280000 - 83544647991490819811253721*x**8/67789839237120000 + 15379466360439848820997927*x**7/2743874445312000 - 86301942586382571444891116749*x**6/4257578514309120000 + 1840844217345700627224331357*x**5/32254382684160000 - 39493678008090950960468485103*x**4/325231692065280000 + 1012864183163027372177729243*x**3/5420528201088000 - 5758152546353534940077291*x**2/29683844910720 + 603041859313120439*x/5032170 - 32644894825
# Average Runtime for n = 50: 2.13083930015564 seconds
#
# Running experiments for n = 50 with Paillier Encryption SMPC:
# Results for n = 50 (Paillier Encryption SMPC):
# Experiment 1 - Runtime: 17.695703744888306 seconds
# Result: 1225
# Experiment 2 - Runtime: 15.035487174987793 seconds
# Result: 1225
# Experiment 3 - Runtime: 15.240119218826294 seconds
# Result: 1225
# Experiment 4 - Runtime: 14.829587459564209 seconds
# Result: 1225
# Experiment 5 - Runtime: 14.278044700622559 seconds
# Result: 1225
# Average Runtime for n = 50: 15.415788459777833 seconds
#
# Running experiments for n = 70 with No Privacy Protection SMPC:
# Results for n = 70 (No Privacy Protection SMPC):
# Experiment 1 - Runtime: 3.6716461181640625e-05 seconds
# Result: 511.66857142857145
# Experiment 2 - Runtime: 2.3603439331054688e-05 seconds
# Result: 515.6342857142857
# Experiment 3 - Runtime: 1.5974044799804688e-05 seconds
# Result: 482.54857142857145
# Experiment 4 - Runtime: 1.2159347534179688e-05 seconds
# Result: 522.4628571428572
# Experiment 5 - Runtime: 1.1444091796875e-05 seconds
# Result: 517.5771428571428
# Average Runtime for n = 70: 1.9979476928710937e-05 seconds
#
#
# Running experiments for n = 70 with Shamir's Secret Sharing SMPC:
# Results for n = 70 (Shamir's Secret Sharing SMPC):
# Experiment 1 - Runtime: 5.082512378692627 seconds
# Result: 11508950622467*x**34/73808199759901035211904652410880000000 - 75330548528743*x**33/789392510801080590501654036480000000 + 14575253350877*x**32/519337178158605651645825024000000 - 74458400186045621*x**31/14096294835733581973243822080000000 + 11208381822024427*x**30/15679972008602427111505920000000 - 20507427929252776361*x**29/276785592847503713359626240000000 + 130900239549330179*x**28/21395673306085183193088000000 - 15122321011791503401499*x**27/36586601353405663260180480000000 + 14814915694052372917489*x**26/636288719189663708872704000000 - 20981938956651259168523*x**25/18920026556383019139072000000 + 234827208180115071181957*x**24/5203007303005330263244800000 - 890490418235264665505249071*x**23/562870790052394819387392000000 + 15288291930335255473321707109*x**22/318144359594831854436352000000 - 808465414657678849714196051387*x**21/636288719189663708872704000000 + 186689450717999303393617417961*x**20/6362887191896637088727040000 - 26952569612515967816284199660521*x**19/45449194227833122062336000000 + 1708708597212407346619685455942847*x**18/162660274078560647380992000000 - 21854472933388028954956361280368471*x**17/133955519829402886078464000000 + 3311578476716410253375458565079239*x**16/1491301685600774317670400000 - 12624929281525234766177283574541739199*x**15/477216539392247781654528000000 + 23768603944443411312823259463058989421*x**14/86338518640044828917760000000 - 32706334729354361713015143443211414583*x**13/13110344488798015979520000000 + 147809796344287950351750555257572586633*x**12/7538448081058859188224000000 - 35083792763931613401547889476440903929377*x**11/263845682837060071587840000000 + 23257351358111296252552605476879316229697*x**10/30087665586682288865280000000 - 28547095724822751596333202764503435166303*x**9/7472753544404751482880000000 + 494583081239348459178722218030879358549*x**8/31136473101686464512000000 - 75124795756200615529434497840995286297*x**7/1369875886978959360000000 + 44830395703356099133349982205456891969*x**6/290065783052370124800000 - 7411182897019912603600565830876604384443*x**5/21319835054349204172800000 + 1593683252778275771267801540327267622019*x**4/2634081070120680660480000 - 77421210514479710787728052513656261*x**3/99343868248681056000 + 16011308516479117124963070486943*x**2/23109547895834400 - 69442067487397927734721387*x/185132760120 + 91736252316283
# Experiment 2 - Runtime: 4.809435606002808 seconds
# Result: 515822527859*x**34/2545110336548311559031194910720000000 - 286618513967*x**33/2331717942752923333920030720000000 + 2019586909922899*x**32/56385179342934327892975288320000000 - 164724337366853057*x**31/24668515962533768453176688640000000 + 2848499528128816591*x**30/3183034317746292703635701760000000 - 5039968288688016653*x**29/54879902030108494890270720000000 + 10171630685706472667*x**28/1355059309385394935562240000000 - 327887296258601234671*x**27/653332167025101129646080000000 + 292401490955580928127861*x**26/10453314672401618074337280000000 - 741848689704147960874921*x**25/562870790052394819387392000000 + 38644143391217708148640681*x**24/728421022420746236854272000000 - 1423290923846540687803526293*x**23/773947336322042876657664000000 + 17571706730424873066400114211*x**22/318144359594831854436352000000 - 4687078377600534969209987177*x**21/3246371016273794433024000000 + 1497924974961938642539204353521*x**20/45449194227833122062336000000 - 1540390654484398517093804589523*x**19/2339296761726704812032000000 + 13127920028010626498288165232877933*x**18/1138621918549924531666944000000 - 5927451451735639065769928566004639*x**17/33488879957350721519616000000 + 185540756182894651017435692278723573*x**16/77912904390571066392576000000 - 50316663934929188946436842883225361*x**15/1794047140572360081408000000 + 540961873533825487972430156312925541693*x**14/1874779261898116285071360000000 - 20391534949888456346068606150592384137*x**13/7886691606542556487680000000 + 21211635031559059457718782615493730688813*x**12/1055382731348240286351360000000 - 17788123832339812450629332575800762494849*x**11/131922841418530035793920000000 + 221703739994779302949282849532480440564469*x**10/285832823073481744220160000000 - 51646828449673956001656569802665447010341*x**9/13611086813022940200960000000 + 2779817499430924128064480242573013643473*x**8/177922703438208368640000000 - 5892847742434718464204949615804183593579*x**7/110275008901806228480000000 + 406425783787361953176267008634611071573*x**6/2722839725970524160000000 - 4436239475025122149104544879879202281993*x**5/13324896908968252608000000 + 1114656412561360909699168097652994606301*x**4/1938683667608820966113280 - 3119580263435369227564132192581192611*x**3/4242567549914261568000 + 191520226325416060117465943001045893*x**2/294877831150846944000 - 217616103668416355314341577*x/622429107300 + 85096454900211
# Experiment 3 - Runtime: 4.797104835510254 seconds
# Result: -724140595877*x**34/1736663523762377299103638880256000000 + 440293751864657*x**33/1736663523762377299103638880256000000 - 8352065540028107*x**32/112770358685868655785950576640000000 + 1365960592589363257*x**31/98674063850135073812706754560000000 - 11841328133043646529*x**30/6366068635492585407271403520000000 + 12825177296650682713*x**29/67011248794658793760751616000000 - 375201077944770163*x**28/23920628540964801085440000000 + 38471467539484582638859*x**27/36586601353405663260180480000000 - 1228596012933849462885643*x**26/20906629344803236148674560000000 + 6251036171567858573310917*x**25/2251483160209579277549568000000 - 2775347013723523339952394241*x**24/24766314762305372053045248000000 + 24116485642401096057209979481*x**23/6191578690576343013261312000000 - 231068996138403549680961599*x**22/1969934115138277736448000000 + 391245219038522024237327933687*x**21/127257743837932741774540800000 - 6396288961078678873046791977313*x**20/90898388455666244124672000000 + 448443563767957284641308962936767*x**19/318144359594831854436352000000 - 3314542450214684443978518701431219*x**18/133955519829402886078464000000 + 10202051200625839473109505105830211*x**17/26791103965880577215692800000 - 39214608738966358045971544438972952621*x**16/7635464630275964506472448000000 + 14466543333065290958674304578075159327*x**15/238608269696123890827264000000 - 468822483555909431581533335926085557399*x**14/749911704759246514028544000000 + 1133469647783078526934819082127956176499*x**13/201899305127489446084608000000 - 92303134745468467650797479213606588275409*x**12/2110765462696480572702720000000 + 4081895716848167902599343064176986117923*x**11/13886614886161056399360000000 - 16989260921223420918803004952630403007263*x**10/10029221862227429621760000000 + 632724344952022480121655051462956434600217*x**9/76222086152928465125376000000 - 7669987692167642208290334221528710330579*x**8/224050811737003130880000000 + 103443102527114248470752758156144644754813*x**7/882200071214449827840000000 - 3576415426833909495185859337665376313617*x**6/10905286472812892160000000 + 78066461292496054931034117558959607167929*x**5/106599175271746020864000000 - 10765065172222220416344596699731101225049*x**4/8502998542143951605760000 + 93506281979528862332246428870114810093*x**3/57698918678833957324800 - 49698373953332000682640929232476457*x**2/34691509547158464000 + 111432719328427542956437619579*x/144403552893600 - 187922557637085
# Experiment 4 - Runtime: 5.465882062911987 seconds
# Result: 74617249453*x**34/80030577131906787977126215680000000 - 9914618975861321*x**33/17366635237623772991036388802560000000 + 13260675350366401*x**32/78939251080108059050165403648000000 - 1248516430619697763*x**31/39469625540054029525082701824000000 + 54529324895931388127*x**30/12732137270985170814542807040000000 - 5654576903232843434851*x**29/12732137270985170814542807040000000 + 107386097156477086477*x**28/2926928108272453060814438400000 - 2791494970743690479791*x**27/1125741580104789638774784000000 + 40900457863413830507499589*x**26/292692810827245306081443840000000 - 29981386166285051018340217*x**25/4502966320419158555099136000000 + 167830381543776908867929709*x**24/619157869057634301326131200000 - 4707831524225993500035507113*x**23/495326295246107441060904960000 + 367493086779548264132318762347*x**22/1272577438379327417745408000000 - 9719192466923709500233600434719*x**21/1272577438379327417745408000000 + 22448345394194609028051082052809*x**20/127257743837932741774540800000 - 453812054736112105150703393228231*x**19/127257743837932741774540800000 + 16926451380015717970831965428205343*x**18/267911039658805772156928000000 - 262916766165266461900155449751879467*x**17/267911039658805772156928000000 + 10200015919111526927980718104284722503*x**16/763546463027596450647244800000 - 179777535446975079145137291421179011*x**15/1129506602111829069004800000 + 43474847991782509842855812851763242531261*x**14/26246909666573627990999040000000 - 30306254454511621250145764678059326394907*x**13/2018993051274894460846080000000 + 24903018770534458884977684179268131282661*x**12/211076546269648057270272000000 - 84442606810878991129830272158681293487463*x**11/105538273134824028635136000000 + 1181748736665686067189947617133897883062579*x**10/254073620509761550417920000000 - 17520642360274850631547941306687389571132401*x**9/762220861529284651253760000000 + 8993818181205593832243522288615173170781*x**8/94101340929541314969600000 - 58219104286394942886315117837735028708763*x**7/176440014242889965568000000 + 1982496329283584486903412245383926007345147*x**6/2131983505434920417280000000 - 445887333489603545537276986762787921027921*x**5/213198350543492041728000000 + 3161608020265843978767305553239550181597*x**4/868585872584597207040000 - 10404486243735970078001591726584527929*x**3/2219189179955152204800 + 72297251917321383115829571781737907*x**2/17345754773579232000 - 20364675476584827549939275153*x/9025222055850 + 551835928581476
# Experiment 5 - Runtime: 4.508843183517456 seconds
# Result: -2720851143623*x**34/14761639951980207042380930482176000000 + 12798168406937*x**33/112770358685868655785950576640000000 - 13254963297670411*x**32/394696255400540295250827018240000000 + 627582332551823443*x**31/98674063850135073812706754560000000 - 2757029930145941287*x**30/3183034317746292703635701760000000 + 575195689010462405279*x**29/6366068635492585407271403520000000 - 91578449274615275041*x**28/12195533784468554420060160000000 + 242622448425893807003*x**27/475150666927346276106240000000 - 2118583913034204706987223*x**26/73173202706811326520360960000000 + 625075841243540156786401*x**25/450296632041915855509913600000 - 704220707808928535870546159*x**24/12383157381152686026522624000000 + 102683452659164807340814009*x**23/51170071822944983580672000000 - 2788737433466646719140048613*x**22/45449194227833122062336000000 + 148453378019362126868225441293*x**21/90898388455666244124672000000 - 12077810237224935268754076536789*x**20/318144359594831854436352000000 + 245727896440429975163293478800643*x**19/318144359594831854436352000000 - 15680513229693496372712503218913969*x**18/1138621918549924531666944000000 + 2621524020124219705918619055045533*x**17/12177774529945716916224000000 - 11257986660931721814018584699367992539*x**16/3817732315137982253236224000000 + 2410222102037692819162635292044404483*x**15/68173791341749683093504000000 - 194324642117529991631167166374407030943*x**14/524938193331472559819980800000 + 309736182199971149341240506272675955053*x**13/91772411421586111856640000000 - 28162698577286019820625704797850816054751*x**12/1055382731348240286351360000000 + 48024466149295279264783327781408906749763*x**11/263845682837060071587840000000 - 304142443914233892775411116323375630638073*x**10/285832823073481744220160000000 + 287859417721386797315394976885693937771947*x**9/54444347252091760803840000000 - 467902459191454072921883105765329197412289*x**8/21172801709146795868160000000 + 768693421456630465207060249851969293359*x**7/10025000809255111680000000 - 154295827317924373520050950662134110056527*x**6/710661168478306805760000000 + 52287903138078173811282186907975788504253*x**5/106599175271746020864000000 - 207744714542043538086973778030978062141999*x**4/242335458451102620764160000 + 581415096151021080697466036596910219*x**3/524535624353035975680 - 5950687439567329800248848925189203*x**2/6017914921445856000 + 2280549812414303845674670667*x/4247163320400 - 131659962102354
# Average Runtime for n = 70: 4.932755613327027 seconds
#
# Running experiments for n = 70 with Paillier Encryption SMPC:
# Results for n = 70 (Paillier Encryption SMPC):
# Experiment 1 - Runtime: 20.1646671295166 seconds
# Result: 2415
# Experiment 2 - Runtime: 27.754513025283813 seconds
# Result: 2415
# Experiment 3 - Runtime: 20.794933557510376 seconds
# Result: 2415
# Experiment 4 - Runtime: 22.05107808113098 seconds
# Result: 2415
# Experiment 5 - Runtime: 25.047443628311157 seconds
# Result: 2415
# Average Runtime for n = 70: 23.162527084350586 seconds
#
# Running experiments for n = 100 with No Privacy Protection SMPC:
# Results for n = 100 (No Privacy Protection SMPC):
# Experiment 1 - Runtime: 4.863739013671875e-05 seconds
# Result: 524.576
# Experiment 2 - Runtime: 3.981590270996094e-05 seconds
# Result: 523.08
# Experiment 3 - Runtime: 3.790855407714844e-05 seconds
# Result: 523.058
# Experiment 4 - Runtime: 3.552436828613281e-05 seconds
# Result: 517.854
# Experiment 5 - Runtime: 3.528594970703125e-05 seconds
# Result: 518.276
# Average Runtime for n = 100: 3.943443298339844e-05 seconds
#
#
# Running experiments for n = 100 with Shamir's Secret Sharing SMPC:
# Results for n = 100 (Shamir's Secret Sharing SMPC):
# Experiment 1 - Runtime: 12.397735834121704 seconds
# Result: 3870608662662109759*x**49/608281864034267560872252163321295376887552831379210240000000000 - 7046820324828802159*x**48/886708256609719476490163503383812502751534739619840000000000 + 14984444521141382668517*x**47/3103478898134018167715572261843343759630371588669440000000000 - 62780125892279511141001*x**46/33015732958872533699101832572801529357769910517760000000000 + 348211604244788916521807*x**45/637985177949227704330470194643507813676713246720000000000 - 1279981675897568838590993*x**44/10516239196965291829623135076541337588077690880000000000 + 1382958454717987313494001071*x**43/62998536380566372057711006681098733952402718720000000000 - 587571163848896867778926857*x**42/178518424373307092991364001734596764180152320000000000 + 10160314369548696930829567847617*x**41/24278505714769764646825504235905159928500715520000000000 - 13562068595928457934067149159951*x**40/296079337984997129839335417511038535713423360000000000 + 148136137820781756351525340350383*x**39/33925757477447587794090516589806498883829760000000000 - 14358200225503973461449863238253*x**38/39243212813704554996056120983003468922880000000000 + 857279329029634038568192303793533721*x**37/31576328289258696672616104083587212257525760000000000 - 2078867827660592977423819875297396623*x**36/1158205091690956055559277949011886163886080000000000 + 123062971269354991532132799428527222199*x**35/1158205091690956055559277949011886163886080000000000 - 3274943739854439432458545137034806633809*x**34/579102545845478027779638974505943081943040000000000 + 76242499054576859107492658380940434670333*x**33/280776991925080255893158290669548160942080000000000 - 6065774902699129957959885013777058099323*x**32/514243574954359443027762437123714580480000000000 + 565758368606129295630495931495560178810847713*x**31/1217717606283771979362719108447279524085760000000000 - 1072797073198609909875701313265644864742161677*x**30/64533421531167639459314607129694536990720000000000 + 1536470981070055014643082730043685183460419481127*x**29/2839470547371376136209842713706559627591680000000000 - 785280434116759278001981237982359721456637697589*x**28/48956388747782347176031770925975165992960000000000 + 54217390025006122671928640195884312468269485621009*x**27/125110771244332665005414525699714313093120000000000 - 76174779098822610079808163207472862263239534943*x**26/7135866643845735484547769441787576320000000000 + 7560258180088883617860620104161159220883140587692831731*x**25/31527914353571831581364460476328006899466240000000000 - 11060681644706783814846168676440323845255373621521663699*x**24/2251993882397987970097461462594857635676160000000000 + 204027178611415494369454856891641893879206721137509801*x**23/2225290397626470326183262314817052999680000000000 - 1734405393380831134446846016014081161920600507929951241*x**22/1112645198813235163091631157408526499840000000000 + 259352565243188192770821580405915038624289259377509770273*x**21/10755570255194606576552434521615756165120000000000 - 1054216901456528650519957671556610884387236236696965951*x**20/3110344203352980502184046998732144640000000000 + 1094985626109790176377481397890397063078135424301032230331011*x**19/253357363807396637153592051346350098350080000000000 - 225733216429808663155012452614355813184432415762144323865467*x**18/4524238639417797092028429488327680327680000000000 + 18829734744288406121789589764463503479091567051958106168273901*x**17/36193909115342376736227435906621442621440000000000 - 88415263280391985866237593389376653594723444526941277106736043*x**16/18096954557671188368113717953310721310720000000000 + 2141747411038977072024384269534476255350612779530361862826133*x**15/52002742981813759678487695268134256640000000000 - 857437228465434411711799711508452629117570836872746465535069*x**14/2762050451415016539699895902519951360000000000 + 78059551636442943607409390936179195477984129307661837897082720363*x**13/37481108324200302171501517697071573893120000000000 - 11037901827464895120331263820801753610317184714841273632316395089*x**12/89240734105238814694051 ...
# Experiment 2 - Runtime: 12.361664533615112 seconds
# Result: -3058306634801258803*x**49/304140932017133780436126081660647688443776415689605120000000000 + 32868416983381211*x**48/2617313007070645724406976396241487463318888120320000000000 - 5919371037593970500899*x**47/775869724533504541928893065460835939907592897167360000000000 + 22044197168311402819769*x**46/7336829546416118599800407238400339857282202337280000000000 - 359610026972748476803*x**45/416983776437403728320568754668959355344257024000000000 + 40899103918363270665346087*x**44/212661725983075901443490064881169271225571082240000000000 - 772825748384899293112091311*x**43/22279970183371034020409990167705649812435107840000000000 + 3507506049386132896167972161*x**42/674402936521382351300708450997365553569464320000000000 - 1605565999858716550901134407137*x**41/2427850571476976464682550423590515992850071552000000000 + 4762776986652241755535911482899*x**40/65795408441110473297630092780230785714094080000000000 - 1872966738850362433054976888849477*x**39/271406059819580702352724132718451991070638080000000000 + 39455542078163135724883886552293*x**38/68226762146702036790528942362607338127360000000000 - 111946681941111588992449309963855361*x**37/2608479293460501029476982511252856664752128000000000 + 730347212482713145367485419517170827*x**36/257378909264656901235395099780419147530240000000000 - 5120558402915686084196390103571214909*x**35/30479081360288317251559946026628583260160000000000 + 1150879788669407579890271816509196528521*x**34/128689454632328450617697549890209573765120000000000 - 12058892528427762933778104291852073407733*x**33/28077699192508025589315829066954816094208000000000 + 11414442638920737352516515852430768678421*x**32/611714579357473324385965774879189893120000000000 - 1286802401627265951212878798735191605034395347*x**31/1750469059032922220333908718392964315873280000000000 + 377284464399385597530384416913979959712380413*x**30/14340760340259475435403246028821008220160000000000 - 71532969281552621269979657978887928448214436879*x**29/83513839628569886359113020991369400811520000000000 + 12012907010173502584796345624018997871825092527*x**28/473008586935095141797408414743721410560000000000 - 42931977116250312164370621163453984621204659748021*x**27/62555385622166332502707262849857156546560000000000 + 54247645516223775965387156204174204846305363027841*x**26/3207968493444427307831141684608059310080000000000 - 1197959557517660239221116448545141030265184000416533027*x**25/3152791435357183158136446047632800689946624000000000 + 3895820703064522125226463356288289582257530854645418151*x**24/500443084977330660021658102798857252372480000000000 - 29407185560212562461761615837147126693925552073178673*x**23/202299127056951847834842028619732090880000000000 + 35956709674407339796676005301231842489850147439228337*x**22/14544381683833139386818707939980738560000000000 - 41145053403747067100925598952493198109525322747140430323*x**21/1075557025519460657655243452161575616512000000000 + 642804759181049794954355681180874495408511513160519076371*x**20/1195063361688289619616937169068417351680000000000 - 3476540856599506092036220156827512428022783296707479243094271*x**19/506714727614793274307184102692700196700160000000000 + 5139308825166620913923393526553835051232517326489551126291*x**18/64863636407423614222629813452726599680000000000 - 157431016478620459457647887505844293427680988965309970310823*x**17/190494258501801982822249662666428645376000000000 + 1836592892495891849795093464097751703587856244292493914462671*x**16/236561497485897887164885202004061716480000000000 - 4292728965405345630468136809092910167675300751527817879843847*x**15/65568675933591262203310572294604062720000000000 + 235661347467980303975384641230055707405493330229956102532803*x**14/477391436047039895750599291793571840000000000 - 730411251583925926024370134574795489182452865431101318545830109*x**13/220477107789413542185303045276891611136000000000 + 11709319654572927300760516181524264359436026838515186691628332183*x**12/594938227368258764627008217413834506240000000000 - 764867356577301 ...
# Experiment 3 - Runtime: 11.985997915267944 seconds
# Result: -2111796641527314943*x**49/608281864034267560872252163321295376887552831379210240000000000 + 1320998451274451*x**48/305280237864845383407001009427832358806843555840000000000 - 4747737576371686207*x**47/1809608686958611176510537762007780617860274978816000000000 + 8511241469596678271117*x**46/8253933239718133424775458143200382339442477629440000000000 - 678692691969738282973*x**45/2297665706899979727480684974706510733529579520000000000 + 1429790647819196599292063*x**44/21749494702814580829447847544665039102615224320000000000 - 864724403541203531268817619*x**43/73078302201456991586944767750074531384787153715200000000 + 386915548127907846586129*x**42/218520536747279707722723792445862974586880000000000 - 19007016742346871170725456319*x**41/84594096567142037096952976431725295918120960000000000 + 1816787874452424772543408121851*x**40/74019834496249282459833854377759633928355840000000000 - 2263545568735959983450365875893*x**39/969307356498502508402586188280185682395136000000000 + 1019331430531129967040443868823877*x**38/5219347304222705814475464090739461366743040000000000 - 8677963824735257524960531426427814971*x**37/599950237495915236779705977588157032892989440000000000 + 433869555620958754843666221095989*x**36/454554588575728436247754297100426280960000000000 - 1866352890157754438235857891918158933*x**35/33091574048313030158836512828911033253888000000000 + 4929606491474678825580313547348512321*x**34/1645177687061017124373974359391883755520000000000 - 1920262737598658732342225327195887552457*x**33/13370332948813345518721823365216579092480000000000 + 4285974189973270955969232443659476849049*x**32/688178901777157489934211496739088629760000000000 - 1371781214573722892912537838939786966407692579*x**31/5601500988905351105068507898857485810794496000000000 + 2880322768476895692712350557922550264991311*x**30/329252150669222650302625546580074168320000000000 - 1356719493022337369604242989117799823207638029*x**29/4772219407346850649092172628078251474944000000000 + 102984265752197545832032451835416492570593589779*x**28/12239097186945586794007942731493791498240000000000 - 2434123947099163028212361820216496485026432044553*x**27/10723780392371371286178387917118369693696000000000 + 54754167817689684479462981222606296055087982991*x**26/9806968899796143264429441291261050880000000000 - 3948613794925686810307604543062959894783328557917254099*x**25/31527914353571831581364460476328006899466240000000000 + 1440820351093590394997279458724471578400715025751839*x**24/562436034564932060463901464184529879040000000000 - 607310097444982252544217976321860064112080010715199*x**23/12715945129294116149618641798954588569600000000 + 451174759678836818088710934734328687199667449625351689*x**22/556322599406617581545815578704263249920000000000 - 19253334965360787314407047135935709431607356718295960051*x**21/1536510036456372368078919217373679452160000000000 + 59133523571791405958572330733347423653347220283124240201*x**20/336111570474831455517263578800492380160000000000 - 28388917254988695573577886105388526605900859655657953660163*x**19/12667868190369831857679602567317504917504000000000 + 16704595492509077142694943067561177414550540512867884179463*x**18/646319805631113870289775641189668618240000000000 - 1392128648819636783916879838030140269001729728904897872813747*x**17/5170558445048910962318205129517348945920000000000 + 39547931512318859054516705693199965986706076593609903960617*x**16/15654804980684419003558579544386437120000000000 - 101872624888232501437804597462264015579728263023777672029031*x**15/4787554115786028668813152897701249024000000000 + 10834516804178425722537348380749732739350607344636980414089*x**14/67602633426241663559088361250488320000000000 - 87737951909934648702685662522785211844553913333222936293144813*x**13/81658188070153163772334461213663559680000000000 + 252168856097688402641980607321098423110155790229962500440177*x**12/39543040635075688893145707467243520000000000 - 1684357720730316953862464441177247542843602328905705632022439*x**11/50589985320430 ...
# Experiment 4 - Runtime: 12.214161396026611 seconds
# Result: 10082163378439*x**49/1547365772343141225495925199490459051679316705280000000000 - 181134698591349361*x**48/22167706415242986912254087584595312568788368490496000000000 + 23875066327365476227*x**47/4789319287243855197091932502844666295725882081280000000000 - 1914524134008163535491*x**46/971050969378603932326524487435339098757938544640000000000 + 6973068322257332391233*x**45/12268945729792840467893657589298227186090639360000000000 - 1218212424357236390412521*x**44/9569777669238415564957052919652617205150698700800000000 + 1755474673017736181178831563*x**43/76123231459851032903067466406327636859153285120000000000 - 5270177868002774135047554403*x**42/1517406607173110290426594014744072495531294720000000000 + 299173748297617611170227529281*x**41/674402936521382351300708450997365553569464320000000000 - 1962298087797736286236689893*x**40/40228170921874610032518399118347627134976000000000 + 105659582254272002349647488015181*x**39/22617171651631725196060344393204332589219840000000000 - 157903970170612157358016261042417*x**38/401488254170977370344266468518420105134080000000000 + 86237968846915667656420005899487023*x**37/2940932536744682533233852831314495259279360000000000 - 112807725473436494293372775106267619*x**36/57910254584547802777963897450594308194304000000000 + 1864000918916053100469938971838541251*x**35/16086181829041056327212193736276196720640000000000 - 1794539571454317166275033448390409812903*x**34/289551272922739013889819487252971540971520000000000 + 130299201017942226502536523882100029*x**33/435694144841505216799120922278625280000000000 - 15274008900129613712443718178739576206793*x**32/1169904133021167732888159544456450670592000000000 + 603125727435856225106577722823308875470173933*x**31/1166979372688614813555939145595309543915520000000000 - 35276544423146585731389374913827172940993067*x**30/1898041809740224689979841386167486382080000000000 + 15986202029720506977379429079454735391834972327*x**29/26291393957142371631572617719505181736960000000000 - 385608919021609879362505313512630115670560557*x**28/21285386412079281380883378663467463475200000000 + 7693254114975203705753725584275117402926146223199*x**27/15638846405541583125676815712464289136640000000000 - 87913058537296921769644991103142949251977215785883*x**26/7217929110249961442620068790368133447680000000000 + 722516079300005377769989810358017731544308887574176369*x**25/2627326196130985965113705039694000574955520000000000 - 31873386316616021859063635469699307371802767005232331*x**24/5629984705994969925243653656487144089190400000000 + 6566009753684768160533207806342810138479864707011663*x**23/61813622156290842393979508744918138880000000000 - 126226023241428139511989412753933626687920304400734549*x**22/69540324925827197693226947338032906240000000000 + 114452961920696937666520175473042977129081823685961227*x**21/4055644892607317713632139714033090560000000000 - 53598539565792807428855381563093072967555938665996201313*x**20/134444628189932582206905431520196952064000000000 + 53931931247465047636902225424650988027895744218470859567597*x**19/10556556825308193214733002139431254097920000000000 - 23317745381512352234025839578881198702334854755181289716007*x**18/393412055601547573219863433767624376320000000000 + 36728016917893981133809019068914895606511709379538922222209*x**17/59140374371474471791221300501015429120000000000 - 662826044789004257296675492757542273795318578539454867170483*x**16/113105965985444927300710737208192008192000000000 + 2079273070784160343641133322852213826722326779330773180567411*x**15/41891098513127750852115087854885928960000000000 - 53435330795929814427019249851213733920413380383456419138827*x**14/142164361469890557190435818512056320000000000 + 2637359715320522794110033861408213365092327998852206966612316919*x**13/1041141897894452838097264380474210385920000000000 - 337136877175564826572411524581925922838390595011541125137924129*x**12/22310183526309703673512808153018793984000000000 + 9099022178193449574247916265371802918755050365218974789596281*x**11/11476 ...
# Experiment 5 - Runtime: 12.450785160064697 seconds
# Result: -539415770370333301*x**49/86897409147752508696036023331613625269650404482744320000000000 + 59578947822350711*x**48/7677127762854714082165917778214826863649651425280000000000 - 861642135751121049943*x**47/182557582243177539277386603637843750566492446392320000000000 + 42797890647286006873*x**46/22999465662746453290910367518496363188972421120000000000 - 1023412749964760833170553*x**45/1913955533847683112991410583930523441030139740160000000000 + 10880279435488626996018817*x**44/91140739707032529190067170663358259096673320960000000000 - 803726303506812435022828403*x**43/37284848061967852850482024362282924175911813120000000000 + 595183182217834855137059599*x**42/183928073596740641263829577544736060064399360000000000 - 526407435637971750034231404799*x**41/1277816090251040244569763380837113680447406080000000000 + 58246549868422003260738807811*x**40/1290106047864911241130001819220211484590080000000000 - 389879491114018734828868289871599*x**39/90468686606526900784241377572817330356879360000000000 + 16340265411381104755840154532037*x**38/45189154149114336056064624162246418759680000000000 - 121204169842335016822927015012791779*x**37/4510904041322670953230872011941030322503680000000000 + 124869052161609923189532539658535729*x**36/70194247981270063973289572667387040235520000000000 - 122144103176985311573372256818746727087*x**35/1158205091690956055559277949011886163886080000000000 + 723409102451780425862563666475715930463*x**34/128689454632328450617697549890209573765120000000000 - 75901653963782968118018541771285782271769*x**33/280776991925080255893158290669548160942080000000000 + 250796351001535475098238637984125330603*x**32/21324294974183964144691903293806346240000000000 - 109201600602930989576101858161114024045835663*x**31/235357184407787861557500331884768311377920000000000 + 715391780930150156081866069771593748822821257*x**30/43022281020778426306209738086463024660480000000000 - 1539409912405611426602822394120170252918262869131*x**29/2839470547371376136209842713706559627591680000000000 + 15921092506776017571065038811172954210502469209*x**28/989017954500653478303672139918690222080000000000 - 163510930756799259074375174023674364478911764417011*x**27/375332313732997995016243577099142939279360000000000 + 122141249934750234694914777720967512363998707307*x**26/11362344132624890110381847761303633920000000000 - 1089481688871286703183964493160929490588028240476682769*x**25/4503987764795975940194922925189715271352320000000000 + 438310411093279250529801089161296690482354299460460911*x**24/88313485584234822356763194611563044536320000000000 - 5435123148809995960614249348146726615648908569322091*x**23/58560273621749219110085850389922447360000000000 + 3948004757895651499273004826484469730373025618669093*x**22/2497520087122862318948667019996692480000000000 - 29274950661376411244103613153342957278613256973631898621*x**21/1195063361688289619616937169068417351680000000000 + 176668581475749142723012788199298254827551700723333021701*x**20/512170012152124122692973072457893150720000000000 - 318962905507174019549438455033482908244080111921918348823233*x**19/72387818230684753472454871813242885242880000000000 + 963648190808972665374144557444403958643294228031160502111*x**18/18910088357023185337631889188412456960000000000 - 19266007057165092710184466330187562809071441983973256081182193*x**17/36193909115342376736227435906621442621440000000000 + 1830786317996108500288292022865950372742585550992079779325063*x**16/365595041569114916527549857642640834560000000000 - 937852996417220144085440731205755091476577534137242358871587*x**15/22177640389302926921707987687880785920000000000 + 10314953347784193020505095770999545148440653924427532001057*x**14/32304683642280895201168373128888320000000000 - 11489534960045859288143593402065501201286755111378740027892991937*x**13/5354444046314328881643073956724510556160000000000 + 690411634240488969501625668941185092100821075120556610261923127*x**12/54085293397114433147909837946712227840000000000 - 49673831120025281500378649604428 ...
# Average Runtime for n = 100: 12.282068967819214 seconds
#
# Running experiments for n = 100 with Paillier Encryption SMPC:
# Results for n = 100 (Paillier Encryption SMPC):
# Experiment 1 - Runtime: 30.155956983566284 seconds
# Result: 4950
# Experiment 2 - Runtime: 28.59376835823059 seconds
# Result: 4950
# Experiment 3 - Runtime: 30.962939023971558 seconds
# Result: 4950
# Experiment 4 - Runtime: 30.98948073387146 seconds
# Result: 4950
# Experiment 5 - Runtime: 31.67679786682129 seconds
# Result: 4950
# Average Runtime for n = 100: 30.475788593292236 seconds
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
# ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="65e2e318-159e-4242-8812-45ba5c2e0d0b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("65e2e318-159e-4242-8812-45ba5c2e0d0b")) {                    Plotly.newPlot(                        "65e2e318-159e-4242-8812-45ba5c2e0d0b",                        [{"hovertemplate":"n=%{x}\u003cbr\u003eRuntime (seconds)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[10,30,50,70,100],"xaxis":"x","y":[0.06394991874694825,0.6106939315795898,2.13083930015564,4.932755613327027,12.282068967819214],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","marke ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="556bb78b-025f-4f55-b7a2-b082b1e82ad6" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("556bb78b-025f-4f55-b7a2-b082b1e82ad6")) {                    Plotly.newPlot(                        "556bb78b-025f-4f55-b7a2-b082b1e82ad6",                        [{"hovertemplate":"n=%{x}\u003cbr\u003eRuntime (seconds)=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"","orientation":"v","showlegend":false,"x":[10,30,50,70,100],"xaxis":"x","y":[6.799634075164795,10.806218433380128,15.415788459777833,23.162527084350586,30.475788593292236],"yaxis":"y","type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","mark ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="f56e61a2-74be-48a7-af2a-cab246476293" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f56e61a2-74be-48a7-af2a-cab246476293")) {                    Plotly.newPlot(                        "f56e61a2-74be-48a7-af2a-cab246476293",                        [{"mode":"lines","name":"No Privacy","x":[10,30,50,70,100],"y":[2.6702880859375e-06,1.0585784912109375e-05,2.32696533203125e-05,1.9979476928710937e-05,3.943443298339844e-05],"type":"scatter"},{"mode":"lines","name":"Shamir's Secret Sharing","x":[10,30,50,70,100],"y":[0.06394991874694825,0.6106939315795898,2.13083930015564,4.932755613327027,12.282068967819214],"type":"scatter"},{"mode":"lines","name":"Paillier Encryption","x":[10,30,50,70,100],"y":[6.799634075164795,10.806218433380128,15.415788459777833,23.162527084350586,30.475788593292236],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line ...
